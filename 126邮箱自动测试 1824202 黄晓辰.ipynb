# %%
# 导入模块
from selenium import webdriver
import unittest
import time
from selenium.webdriver.common.keys import Keys

# from selenium import webdriver 模拟浏览器的开启、关闭、打开网页、操作界面元素。
# import unittest 单元测试，它封装了校验返回的结果方法和用例执行前初始化操作。
# import time 时间模块。
# from selenium.webdriver.common.keys import Keys 导入模拟键盘模块。

#定义一个类，类中必须继承:unittest.TestCase
class test(unittest.TestCase):
    # 初始化函数。每个测试用例被执行时，都会被调用
    def setUp(self):
        # 创建谷歌浏览器对象
        self.driver = webdriver.Chrome()
        # 浏览器最大化
        self.driver.maximize_window()
    
    # 测试用例函数，必须以test开头
    def testLogin(self):
        # 打开网页
        self.driver.get("https://www.126.com")
        # 延迟2秒，等待浏览器刷新出来
        time.sleep(2)
        # 通过xpath的方式切换到iframe元素
        self.driver.switch_to.frame(self.driver.find_element_by_xpath("//iframe[starts-with(@id,'x-URS-iframe')]"))
        
        # 点击用户名输入框
        user = self.driver.find_element_by_name("email")
        # 延迟2秒
        time.sleep(2)
        # 输入用户名
        user.send_keys("huangxiaochen0621")
        #点击密码输入框
        password = self.driver.find_element_by_name("password")
        # 延迟2秒
        time.sleep(2)
        # 输入密码
        password.send_keys("hxc06214018")
        
        # 查找登录按钮
        login_btn = self.driver.find_element_by_id("dologin")
        # 延迟2秒
        time.sleep(2)
        # 点击登录按钮
        login_btn.click()
        # 延迟5秒等待登录完成
        time.sleep(5)
        
        # 查找写信按钮
        write_letter_btn = self.driver.find_element_by_id("_mail_component_132_132")
        # 延迟2秒
        time.sleep(2)
        # 点击写信按钮
        write_letter_btn.click()
        
        # 释放iframe
        self.driver.switch_to.default_content()
        # 查找写信人邮件输入框
        receipt_name = self.driver.find_element_by_xpath('//input[@class="nui-editableAddr-ipt"]')
        # 延迟1秒
        time.sleep(1)
        # 输入收件人邮箱
        receipt_name.send_keys("1360970144@qq.com")
        # 延迟1秒
        time.sleep(1)
        
        # 查找主题输入框
        theme_name = self.driver.find_element_by_xpath('//input[contains(@id,"subjectInput")]')
        # 延迟1秒
        time.sleep(1)
        # 输入主题
        theme_name.send_keys("1824202黄晓辰")
        # 延迟1秒
        time.sleep(1)
        
        # 切换iframe，写入文件内容
        self.driver.switch_to.frame(self.driver.find_element_by_xpath('//iframe[@class="APP-editor-iframe"]'))
        # 延迟1秒
        time.sleep(1)
        # 查找写邮件正文框
        content_name = self.driver.find_element_by_xpath('//body[@class="nui-scroll"]')
        # 延迟1秒
        time.sleep(1)
        # 输入正文
        content_name.send_keys("1824202黄晓辰")
        # 切换回默认的iframe
        self.driver.switch_to_default_content()
        # 延迟5秒
        time.sleep(5)
        
        # 查找发送按钮
        send_btn = self.driver.find_element_by_xpath('//footer[contains(@class,"jp")]/div[@role="button"]/span[.="发送"]')
        # 延迟5秒
        time.sleep(5)
        # 点击发送按钮
        send_btn.click()
        # 延迟1秒
        time.sleep(1)
        
        # 判断邮件是否发送成功
        assert "发送成功" in self.driver.page_source, "发送失败"
        print("邮件发送成功")
        
    # 结束函数，每个测试用例调用结束后，都会被调用
    def tearDown(self):
        # 延迟5秒
        time.sleep(5)
        # 退出
        self.driver.quit()
    
    def testLogin_1(self):
        # 打开网页
        self.driver.get("https://www.126.com")
        # 延迟2秒，等待浏览器刷新出来
        time.sleep(2)
        # 通过xpath的方式切换到iframe元素
        self.driver.switch_to.frame(self.driver.find_element_by_xpath("//iframe[starts-with(@id,'x-URS-iframe')]"))
        
        # 点击用户名输入框
        user = self.driver.find_element_by_name("email")
        # 延迟2秒
        time.sleep(2)
        # 输入用户名
        user.send_keys("1")
        #点击密码输入框
        password = self.driver.find_element_by_name("password")
        # 延迟2秒
        time.sleep(2)
        # 输入密码
        password.send_keys("hxc06214018")
        
        # 查找登录按钮
        login_btn = self.driver.find_element_by_id("dologin")
        # 延迟2秒
        time.sleep(2)
        # 点击登录按钮
        login_btn.click()
        # 延迟5秒等待登录完成
        time.sleep(5)
        
        # 判断邮箱账号是否登录成功
        assert "账号或密码错误" in self.driver.page_source,"登录成功"
        print("测试1，登录失败，账号或密码错误！")
        
    def testLogin_2(self):
        # 打开网页
        self.driver.get("https://www.126.com")
        # 延迟2秒，等待浏览器刷新出来
        time.sleep(2)
        # 通过xpath的方式切换到iframe元素
        self.driver.switch_to.frame(self.driver.find_element_by_xpath("//iframe[starts-with(@id,'x-URS-iframe')]"))
        
        # 点击用户名输入框
        user = self.driver.find_element_by_name("email")
        # 延迟2秒
        time.sleep(2)
        # 输入用户名
        user.send_keys("")
        #点击密码输入框
        password = self.driver.find_element_by_name("password")
        # 延迟2秒
        time.sleep(2)
        # 输入密码
        password.send_keys("hxc06214018")
        
        # 查找登录按钮
        login_btn = self.driver.find_element_by_id("dologin")
        # 延迟2秒
        time.sleep(2)
        # 点击登录按钮
        login_btn.click()
        # 延迟5秒等待登录完成
        time.sleep(5)
        
        # 判断邮箱账号是否登录成功
        assert "请输入账号" in self.driver.page_source,"登录成功"
        print("测试2，登录失败，请输入账号！")
        
    def testLogin_3(self):
        # 打开网页
        self.driver.get("https://www.126.com")
        # 延迟2秒，等待浏览器刷新出来
        time.sleep(2)
        # 通过xpath的方式切换到iframe元素
        self.driver.switch_to.frame(self.driver.find_element_by_xpath("//iframe[starts-with(@id,'x-URS-iframe')]"))
        
        # 点击用户名输入框
        user = self.driver.find_element_by_name("email")
        # 延迟2秒
        time.sleep(2)
        # 输入用户名
        user.send_keys("hxc621@")
        #点击密码输入框
        password = self.driver.find_element_by_name("password")
        # 延迟2秒
        time.sleep(2)
        # 输入密码
        password.send_keys("hxc06214018")
        
        # 查找登录按钮
        login_btn = self.driver.find_element_by_id("dologin")
        # 延迟2秒
        time.sleep(2)
        # 点击登录按钮
        login_btn.click()
        # 延迟5秒等待登录完成
        time.sleep(5)
        
        # 判断邮箱账号是否登录成功
        assert "账号格式错误" in self.driver.page_source,"登录成功"
        print("测试3，登录失败，账号格式错误！")
        
    def testLogin_4(self):
        # 打开网页
        self.driver.get("https://www.126.com")
        # 延迟2秒，等待浏览器刷新出来
        time.sleep(2)
        # 通过xpath的方式切换到iframe元素
        self.driver.switch_to.frame(self.driver.find_element_by_xpath("//iframe[starts-with(@id,'x-URS-iframe')]"))
        
        # 点击用户名输入框
        user = self.driver.find_element_by_name("email")
        # 延迟2秒
        time.sleep(2)
        # 输入用户名
        user.send_keys("huangxiaochen0621")
        #点击密码输入框
        password = self.driver.find_element_by_name("password")
        # 延迟2秒
        time.sleep(2)
        # 输入密码
        password.send_keys("1")
        
        # 查找登录按钮
        login_btn = self.driver.find_element_by_id("dologin")
        # 延迟2秒
        time.sleep(2)
        # 点击登录按钮
        login_btn.click()
        # 延迟5秒等待登录完成
        time.sleep(5)
        
        # 判断邮箱账号是否登录成功
        assert "账号或密码错误" in self.driver.page_source,"登录成功"
        print("测试4，登录失败，账号或密码错误！")
        
    def testLogin_5(self):
        # 打开网页
        self.driver.get("https://www.126.com")
        # 延迟2秒，等待浏览器刷新出来
        time.sleep(2)
        # 通过xpath的方式切换到iframe元素
        self.driver.switch_to.frame(self.driver.find_element_by_xpath("//iframe[starts-with(@id,'x-URS-iframe')]"))
        
        # 点击用户名输入框
        user = self.driver.find_element_by_name("email")
        # 延迟2秒
        time.sleep(2)
        # 输入用户名
        user.send_keys("huangxiaochen0621")
        #点击密码输入框
        password = self.driver.find_element_by_name("password")
        # 延迟2秒
        time.sleep(2)
        # 输入密码
        password.send_keys("")
        
        # 查找登录按钮
        login_btn = self.driver.find_element_by_id("dologin")
        # 延迟2秒
        time.sleep(2)
        # 点击登录按钮
        login_btn.click()
        # 延迟5秒等待登录完成
        time.sleep(5)
        
        # 判断邮箱账号是否登录成功
        assert "请输入密码" in self.driver.page_source,"登录成功"
        print("测试5，登录失败，请输入密码！")
    
    def testLogin_6(self):
        # 打开网页
        self.driver.get("https://www.126.com")
        # 延迟2秒，等待浏览器刷新出来
        time.sleep(2)
        # 通过xpath的方式切换到iframe元素
        self.driver.switch_to.frame(self.driver.find_element_by_xpath("//iframe[starts-with(@id,'x-URS-iframe')]"))
        
        # 点击用户名输入框
        user = self.driver.find_element_by_name("email")
        # 延迟2秒
        time.sleep(2)
        # 输入用户名
        user.send_keys("huangxiaochen0621")
        #点击密码输入框
        password = self.driver.find_element_by_name("password")
        # 延迟2秒
        time.sleep(2)
        # 输入密码
        password.send_keys("hxc06214018")
        
        # 查找登录按钮
        login_btn = self.driver.find_element_by_id("dologin")
        # 延迟2秒
        time.sleep(2)
        # 点击登录按钮
        login_btn.click()
        # 延迟5秒等待登录完成
        time.sleep(5)
        
        # 查找写信按钮
        write_letter_btn = self.driver.find_element_by_id("_mail_component_132_132")
        # 延迟2秒
        time.sleep(2)
        # 点击写信按钮
        write_letter_btn.click()
        
        # 释放iframe
        self.driver.switch_to.default_content()
        # 查找写信人邮件输入框
        receipt_name = self.driver.find_element_by_xpath('//input[@class="nui-editableAddr-ipt"]')
        # 延迟1秒
        time.sleep(1)
        # 输入收件人邮箱
        receipt_name.send_keys("dkdskbdk cksdhc")
        # 延迟1秒
        time.sleep(1)
        
        # 查找主题输入框
        theme_name = self.driver.find_element_by_xpath('//input[contains(@id,"subjectInput")]')
        # 延迟1秒
        time.sleep(1)
        # 输入主题
        theme_name.send_keys("1824202黄晓辰")
        # 延迟1秒
        time.sleep(1)
        
        # 切换iframe，写入文件内容
        self.driver.switch_to.frame(self.driver.find_element_by_xpath('//iframe[@class="APP-editor-iframe"]'))
        # 延迟1秒
        time.sleep(1)
        # 查找写邮件正文框
        content_name = self.driver.find_element_by_xpath('//body[@class="nui-scroll"]')
        # 延迟1秒
        time.sleep(1)
        # 输入正文
        content_name.send_keys("1824202黄晓辰")
        # 切换回默认的iframe
        self.driver.switch_to_default_content()
        # 延迟5秒
        time.sleep(5)
        
        # 查找发送按钮
        send_btn = self.driver.find_element_by_xpath('//footer[contains(@class,"jp")]/div[@role="button"]/span[.="发送"]')
        # 延迟5秒
        time.sleep(5)
        # 点击发送按钮
        send_btn.click()
        # 延迟1秒
        time.sleep(1)
        
        # 判断邮件是否发送成功
        assert "以下邮箱地址无效，将无法成功收到邮件！" in self.driver.page_source, "发送成功"
        print("测试6，以下邮箱地址无效，将无法成功收到邮件！")
        
    def testLogin_6(self):
        # 打开网页
        self.driver.get("https://www.126.com")
        # 延迟2秒，等待浏览器刷新出来
        time.sleep(2)
        # 通过xpath的方式切换到iframe元素
        self.driver.switch_to.frame(self.driver.find_element_by_xpath("//iframe[starts-with(@id,'x-URS-iframe')]"))
        
        # 点击用户名输入框
        user = self.driver.find_element_by_name("email")
        # 延迟2秒
        time.sleep(2)
        # 输入用户名
        user.send_keys("huangxiaochen0621")
        #点击密码输入框
        password = self.driver.find_element_by_name("password")
        # 延迟2秒
        time.sleep(2)
        # 输入密码
        password.send_keys("hxc06214018")
        
        # 查找登录按钮
        login_btn = self.driver.find_element_by_id("dologin")
        # 延迟2秒
        time.sleep(2)
        # 点击登录按钮
        login_btn.click()
        # 延迟5秒等待登录完成
        time.sleep(5)
        
        # 查找写信按钮
        write_letter_btn = self.driver.find_element_by_id("_mail_component_132_132")
        # 延迟2秒
        time.sleep(2)
        # 点击写信按钮
        write_letter_btn.click()
        
        # 释放iframe
        self.driver.switch_to.default_content()
        # 查找写信人邮件输入框
        receipt_name = self.driver.find_element_by_xpath('//input[@class="nui-editableAddr-ipt"]')
        # 延迟1秒
        time.sleep(1)
        # 输入收件人邮箱
        receipt_name.send_keys("dkdskbdk cksdhc")
        # 延迟1秒
        time.sleep(1)
        
        # 查找主题输入框
        theme_name = self.driver.find_element_by_xpath('//input[contains(@id,"subjectInput")]')
        # 延迟1秒
        time.sleep(1)
        # 输入主题
        theme_name.send_keys("1824202黄晓辰")
        # 延迟1秒
        time.sleep(1)
        
        # 切换iframe，写入文件内容
        self.driver.switch_to.frame(self.driver.find_element_by_xpath('//iframe[@class="APP-editor-iframe"]'))
        # 延迟1秒
        time.sleep(1)
        # 查找写邮件正文框
        content_name = self.driver.find_element_by_xpath('//body[@class="nui-scroll"]')
        # 延迟1秒
        time.sleep(1)
        # 输入正文
        content_name.send_keys("1824202黄晓辰")
        # 切换回默认的iframe
        self.driver.switch_to_default_content()
        # 延迟5秒
        time.sleep(5)
        
        # 查找发送按钮
        send_btn = self.driver.find_element_by_xpath('//footer[contains(@class,"jp")]/div[@role="button"]/span[.="发送"]')
        # 延迟5秒
        time.sleep(5)
        # 点击发送按钮
        send_btn.click()
        # 延迟1秒
        time.sleep(1)
        
        # 判断邮件是否发送成功
        assert "以下邮箱地址无效，将无法成功收到邮件！" in self.driver.page_source, "发送成功"
        print("测试6，以下邮箱地址无效，将无法成功收到邮件！")
        
    def testLogin_7(self):
        # 打开网页
        self.driver.get("https://www.126.com")
        # 延迟2秒，等待浏览器刷新出来
        time.sleep(2)
        # 通过xpath的方式切换到iframe元素
        self.driver.switch_to.frame(self.driver.find_element_by_xpath("//iframe[starts-with(@id,'x-URS-iframe')]"))
        
        # 点击用户名输入框
        user = self.driver.find_element_by_name("email")
        # 延迟2秒
        time.sleep(2)
        # 输入用户名
        user.send_keys("huangxiaochen0621")
        #点击密码输入框
        password = self.driver.find_element_by_name("password")
        # 延迟2秒
        time.sleep(2)
        # 输入密码
        password.send_keys("hxc06214018")
        
        # 查找登录按钮
        login_btn = self.driver.find_element_by_id("dologin")
        # 延迟2秒
        time.sleep(2)
        # 点击登录按钮
        login_btn.click()
        # 延迟5秒等待登录完成
        time.sleep(5)
        
        # 查找写信按钮
        write_letter_btn = self.driver.find_element_by_id("_mail_component_132_132")
        # 延迟2秒
        time.sleep(2)
        # 点击写信按钮
        write_letter_btn.click()
        
        # 释放iframe
        self.driver.switch_to.default_content()
        # 查找写信人邮件输入框
        receipt_name = self.driver.find_element_by_xpath('//input[@class="nui-editableAddr-ipt"]')
        # 延迟1秒
        time.sleep(1)
        # 输入收件人邮箱
        receipt_name.send_keys("")
        # 延迟1秒
        time.sleep(1)
        
        # 查找主题输入框
        theme_name = self.driver.find_element_by_xpath('//input[contains(@id,"subjectInput")]')
        # 延迟1秒
        time.sleep(1)
        # 输入主题
        theme_name.send_keys("1824202黄晓辰")
        # 延迟1秒
        time.sleep(1)
        
        # 切换iframe，写入文件内容
        self.driver.switch_to.frame(self.driver.find_element_by_xpath('//iframe[@class="APP-editor-iframe"]'))
        # 延迟1秒
        time.sleep(1)
        # 查找写邮件正文框
        content_name = self.driver.find_element_by_xpath('//body[@class="nui-scroll"]')
        # 延迟1秒
        time.sleep(1)
        # 输入正文
        content_name.send_keys("1824202黄晓辰")
        # 切换回默认的iframe
        self.driver.switch_to_default_content()
        # 延迟5秒
        time.sleep(5)
        
        # 查找发送按钮
        send_btn = self.driver.find_element_by_xpath('//footer[contains(@class,"jp")]/div[@role="button"]/span[.="发送"]')
        # 延迟5秒
        time.sleep(5)
        # 点击发送按钮
        send_btn.click()
        # 延迟1秒
        time.sleep(1)
        
        # 判断邮件是否发送成功
        assert "请填写收件人地址后再发送！" in self.driver.page_source, "发送成功"
        print("测试7，请填写收件人地址后再发送！")
        
    def testLogin_8(self):
        # 打开网页
        self.driver.get("https://www.126.com")
        # 延迟2秒，等待浏览器刷新出来
        time.sleep(2)
        # 通过xpath的方式切换到iframe元素
        self.driver.switch_to.frame(self.driver.find_element_by_xpath("//iframe[starts-with(@id,'x-URS-iframe')]"))
        
        # 点击用户名输入框
        user = self.driver.find_element_by_name("email")
        # 延迟2秒
        time.sleep(2)
        # 输入用户名
        user.send_keys("huangxiaochen0621")
        #点击密码输入框
        password = self.driver.find_element_by_name("password")
        # 延迟2秒
        time.sleep(2)
        # 输入密码
        password.send_keys("hxc06214018")
        
        # 查找登录按钮
        login_btn = self.driver.find_element_by_id("dologin")
        # 延迟2秒
        time.sleep(2)
        # 点击登录按钮
        login_btn.click()
        # 延迟5秒等待登录完成
        time.sleep(5)
        
        # 查找写信按钮
        write_letter_btn = self.driver.find_element_by_id("_mail_component_132_132")
        # 延迟2秒
        time.sleep(2)
        # 点击写信按钮
        write_letter_btn.click()
        
        # 释放iframe
        self.driver.switch_to.default_content()
        # 查找写信人邮件输入框
        receipt_name = self.driver.find_element_by_xpath('//input[@class="nui-editableAddr-ipt"]')
        # 延迟1秒
        time.sleep(1)
        # 输入收件人邮箱
        receipt_name.send_keys("1360970144@qq.com")
        # 延迟1秒
        time.sleep(1)
        
        # 查找主题输入框
        theme_name = self.driver.find_element_by_xpath('//input[contains(@id,"subjectInput")]')
        # 延迟1秒
        time.sleep(1)
        # 输入主题
        theme_name.send_keys("")
        # 延迟1秒
        time.sleep(1)
        
        # 切换iframe，写入文件内容
        self.driver.switch_to.frame(self.driver.find_element_by_xpath('//iframe[@class="APP-editor-iframe"]'))
        # 延迟1秒
        time.sleep(1)
        # 查找写邮件正文框
        content_name = self.driver.find_element_by_xpath('//body[@class="nui-scroll"]')
        # 延迟1秒
        time.sleep(1)
        # 输入正文
        content_name.send_keys("1824202黄晓辰")
        # 切换回默认的iframe
        self.driver.switch_to_default_content()
        # 延迟5秒
        time.sleep(5)
        
        # 查找发送按钮
        send_btn = self.driver.find_element_by_xpath('//footer[contains(@class,"jp")]/div[@role="button"]/span[.="发送"]')
        # 延迟5秒
        time.sleep(5)
        # 点击发送按钮
        send_btn.click()
        # 延迟1秒
        time.sleep(1)
        
        # 判断邮件是否发送成功
        assert "确定真的不需要写主题吗？" in self.driver.page_source, "发送成功"
        print("测试8，确定真的不需要写主题吗？")
        
    def testLogin_9(self):
        # 打开网页
        self.driver.get("https://www.126.com")
        # 延迟2秒，等待浏览器刷新出来
        time.sleep(2)
        # 通过xpath的方式切换到iframe元素
        self.driver.switch_to.frame(self.driver.find_element_by_xpath("//iframe[starts-with(@id,'x-URS-iframe')]"))
        
        # 点击用户名输入框
        user = self.driver.find_element_by_name("email")
        # 延迟2秒
        time.sleep(2)
        # 输入用户名
        user.send_keys("huangxiaochen0621")
        #点击密码输入框
        password = self.driver.find_element_by_name("password")
        # 延迟2秒
        time.sleep(2)
        # 输入密码
        password.send_keys("hxc06214018")
        
        # 查找登录按钮
        login_btn = self.driver.find_element_by_id("dologin")
        # 延迟2秒
        time.sleep(2)
        # 点击登录按钮
        login_btn.click()
        # 延迟5秒等待登录完成
        time.sleep(5)
        
        # 查找写信按钮
        write_letter_btn = self.driver.find_element_by_id("_mail_component_132_132")
        # 延迟2秒
        time.sleep(2)
        # 点击写信按钮
        write_letter_btn.click()
        
        # 释放iframe
        self.driver.switch_to.default_content()
        # 查找写信人邮件输入框
        receipt_name = self.driver.find_element_by_xpath('//input[@class="nui-editableAddr-ipt"]')
        # 延迟1秒
        time.sleep(1)
        # 输入收件人邮箱
        receipt_name.send_keys("1360970144@qq.com")
        # 延迟1秒
        time.sleep(1)
        
        # 查找主题输入框
        theme_name = self.driver.find_element_by_xpath('//input[contains(@id,"subjectInput")]')
        # 延迟1秒
        time.sleep(1)
        # 输入主题
        theme_name.send_keys("1824202黄晓辰")
        # 延迟1秒
        time.sleep(1)
        
        # 切换iframe，写入文件内容
        self.driver.switch_to.frame(self.driver.find_element_by_xpath('//iframe[@class="APP-editor-iframe"]'))
        # 延迟1秒
        time.sleep(1)
        # 查找写邮件正文框
        content_name = self.driver.find_element_by_xpath('//body[@class="nui-scroll"]')
        # 延迟1秒
        time.sleep(1)
        # 输入正文
        content_name.send_keys("")
        # 切换回默认的iframe
        self.driver.switch_to_default_content()
        # 延迟5秒
        time.sleep(5)
        
        # 查找发送按钮
        send_btn = self.driver.find_element_by_xpath('//footer[contains(@class,"jp")]/div[@role="button"]/span[.="发送"]')
        # 延迟5秒
        time.sleep(5)
        # 点击发送按钮
        send_btn.click()
        # 延迟1秒
        time.sleep(1)
        
        # 判断邮件是否发送成功
        assert "确定真的不需要写主题吗？" in self.driver.page_source, "发送成功"
        print("测试9，确定真的不需要写主题吗？")
        
suite=unittest.TestSuite()
suite.addTest(test('testLogin'))
suite.addTest(test('testLogin_1'))
suite.addTest(test('testLogin_2'))
suite.addTest(test('testLogin_3'))
suite.addTest(test('testLogin_4'))
suite.addTest(test('testLogin_5'))
suite.addTest(test('testLogin_6'))
suite.addTest(test('testLogin_7'))
suite.addTest(test('testLogin_8'))
suite.addTest(test('testLogin_9'))
runner=unittest.TextTestRunner()
runner.run(suite)
# Out:
# EEEE
# ...
# ERROR: testLogin (__main__.test)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-30-1bd85d52b2ed>", line 28, in testLogin
#     self.driver.switch_to.frame(self.driver.find_element_by_xpath("//iframe[starts-with(@id,'x-URS-iframe')]"))
#   File "c:\users\13609\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "c:\users\13609\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 978, in find_element
#     'value': value})['value']
#   File "c:\users\13609\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
# ...
